# %% [markdown]
# ### Data structures

# %% [markdown]
# The main data structures in Python are
#
# 1. strings
# 2. lists
# 3. tuples
# 4. dictionaries
# 5. sets
#
# (SLTDS)
#
# We saw some examples of lists, when we discussed for loops. And we saw briefly tuples
# when we introduced argument packing and unpacking. Let's get into more details now.
