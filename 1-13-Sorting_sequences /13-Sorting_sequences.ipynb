# %%
L=[5,3,7,1]

L.sort()  #Here we call sort method of the object L
print(L)
# Out:
# [1, 3, 5, 7]

# %%
L2=[6,1,7,3,6]

# %%
print(sorted(L2))
# Out:
# [1, 3, 6, 6, 7]

# %%
print(L2)
# Out:
# [6, 1, 7, 3, 6]

# %% [markdown]
# The parameter ```reverse=True``` can be given (both to ```sort``` and ```sorted```) to get descending order of elements:

# %%
L=[5,3,7,1]
print(sorted(L, reverse=True))
# Out:
# [7, 5, 3, 1]
