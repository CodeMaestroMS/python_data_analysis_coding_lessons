# %%
L=[]
for i in range(10):
    L.append(i**2)

print(L)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# { a³ : a ∈ {1,2,3,....10}}

L =[a**3 for a in range(1,11)]
print(L)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
