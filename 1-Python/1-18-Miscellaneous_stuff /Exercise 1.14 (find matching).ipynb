# %% [markdown]
# <img src="images/image1.png" width=600>

# %%
L=["sensitive", "engine", "rubbish", "comment"]

# %%
s='en'
L1=[]
[i for i,v in enumerate(L) if s in v]
# Out:
# [0, 1, 3]

# %%
def find_matching(l, st):
    return [i for i,v in enumerate(l) if st in v]

# %%
find_matching(L,s)
# Out:
# [0, 1, 3]
