# %% [markdown]
# <image src='images/image1.png' width=1000>

# %%
def interleave(*l):
    r=[]
    for i in zip(*l):
        r.extend(i)
    return r

# %%
interleave([1,2,3], [20,30,40], ['a', 'b', 'c'])
# Out:
# [1, 20, 'a', 2, 30, 'b', 3, 40, 'c']
