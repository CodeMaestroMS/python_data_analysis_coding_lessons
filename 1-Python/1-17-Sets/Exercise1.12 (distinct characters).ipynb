# %% [markdown]
# <img src="images/image1.png" witch=1000>

# %%
def distinct_characters(l):
    return {word : len(set(word)) for word in l}

# %%
l = ["check", "look", "try", "pop"]

# %%
distinct_characters(l)
# Out:
# {'check': 4, 'look': 3, 'try': 3, 'pop': 2}
